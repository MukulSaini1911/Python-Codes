# %%
x = "Mukul"
print("Hi {} Saini".format(x))
# Out:
# Hi Mukul Saini

# %%
print(x[:4])
# Out:
# Muku

# %%
l1 = list(range(0, 10, 2))

# %%
l1
# Out:
# [0, 2, 4, 6, 8]

# %%
l1.sort(reverse = True)

# %%
print(l1)
# Out:
# [8, 6, 4, 2, 0]

# %%
print(l1[0])
# Out:
# 8

# %%
days = ("Monday", "Tuesday", "Wednesday", "Thursday", "Friday")
print(days[2])
# Out:
# Wednesday

# %%
import numpy as np
c = np.array([[(1.5,2,3), (4,5,6)], [(3,2,1), (4,5,6)]], dtype = float)
print(c)
print(type(c))
# Out:
# [[[1.5 2.  3. ]
#   [4.  5.  6. ]]
#
#  [[3.  2.  1. ]
#   [4.  5.  6. ]]]
# <class 'numpy.ndarray'>

# %%
arr1 = np.array([1, 2, 3, 5])
print(arr1)
# Out:
# [1 2 3 5]

# %%
c
# Out:
# array([[[1.5, 2. , 3. ],
#         [4. , 5. , 6. ]],
#
#        [[3. , 2. , 1. ],
#         [4. , 5. , 6. ]]])

# %%
c.shape
# Out:
# (2, 2, 3)

# %%
c.dtype
# Out:
# dtype('float64')

# %%
rand_arr = np.random.random((2,2))

# %%
rand_arr
# Out:
# array([[0.11070429, 0.79078463],
#        [0.1660105 , 0.30871956]])

# %%
rand_arr1 = np.random.rand(2,2)

# %%
rand_arr1
# Out:
# array([[0.53803724, 0.10068351],
#        [0.51624758, 0.86836691]])

# %%
rand_arr2 = np.random.randn(2,2)

# %%
rand_arr2
# Out:
# array([[-0.27181709,  1.03606798],
#        [-0.50600797, -0.16021226]])

# %%
arr2 = np.diag([1,2,3])

# %%
arr2
# Out:
# array([[1, 0, 0],
#        [0, 2, 0],
#        [0, 0, 3]])

# %%
import numpy as np
arr3 = np.diag =([0,0,0])

# %%
arr3
# Out:
# [0, 0, 0]
